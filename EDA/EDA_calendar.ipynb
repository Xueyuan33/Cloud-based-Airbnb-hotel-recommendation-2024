# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('drive/MyDrive/data/master_CSVs/master_calendar.csv', low_memory=False)
df.head()

# %%
import pandas as pd
chunk_size = 10000  # Number of rows per chunk
chunks = pd.read_csv('drive/MyDrive/data/master_CSVs/master_calendar.csv', chunksize=chunk_size)

# Process each chunk
for chunk in chunks:
    # Perform operations on each chunk
    print(chunk.head())  # Example operation
# Out:
#           listing_id        date available  price  adjusted_price  \
# 17730000    29898335  2024-10-09         f    NaN             NaN
# 17730001    29898335  2024-10-10         f    NaN             NaN
# 17730002    29898335  2024-10-11         f    NaN             NaN
# 17730003    29898335  2024-10-12         f    NaN             NaN
# 17730004    29898335  2024-10-13         f    NaN             NaN
#
#           minimum_nights  maximum_nights state       city
# 17730000             5.0          1125.0    CA  San Diego
# 17730001             5.0          1125.0    CA  San Diego
# 17730002             5.0          1125.0    CA  San Diego
# 17730003             5.0          1125.0    CA  San Diego
# 17730004             5.0          1125.0    CA  San Diego
#           listing_id        date available  price  adjusted_price  \
# 17740000    30248080  2024-02-26         f    NaN             NaN
# 17740001    30248080  2024-02-27         f    NaN             NaN
# ...

# %% [markdown]
# **'price' and 'adjusted_price' all null.**
